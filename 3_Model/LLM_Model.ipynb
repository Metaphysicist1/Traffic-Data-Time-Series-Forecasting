# %% [markdown]
# <a href="https://colab.research.google.com/github/Metaphysicist1/Traffic-Data-Time-Series-Forecasting/blob/main/LLM_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Dropout, Layer, Add, ReLU, Lambda, Permute
from tensorflow.keras.models import Model
import os
import matplotlib.pyplot as plt

# Data Loading and Preprocessing

def load_data():
    npz_file = 'pems08.npz'
    distance_csv = 'distance.csv'

    if not os.path.exists(npz_file) or not os.path.exists(distance_csv):
        raise FileNotFoundError(
            f"Ensure both '{npz_file}' and '{distance_csv}' are in the directory."
        )

    with np.load(npz_file) as data:
        traffic_data = data['data']
        num_sensors = traffic_data.shape[1]

    distance_df = pd.read_csv(distance_csv)
    dist_mx = np.full((num_sensors, num_sensors), np.inf, dtype=np.float32)
    np.fill_diagonal(dist_mx, 0)

    for _, row in distance_df.iterrows():
        from_node, to_node, distance = int(row['from']), int(row['to']), row['cost']
        if from_node < num_sensors and to_node < num_sensors:
            dist_mx[from_node, to_node] = distance
            dist_mx[to_node, from_node] = distance

    return traffic_data, dist_mx

def get_normalized_adj(adj_mx, sigma2=0.1, epsilon=0.5):
    """
    Computes the symmetrically normalized adjacency matrix.
    """
    distances = adj_mx[~np.isinf(adj_mx)].flatten()
    std = distances.std()
    adj = np.exp(-np.square(adj_mx / std))
    adj[adj < epsilon] = 0

    adj = adj + np.identity(adj.shape[0])
    d = np.sum(adj, axis=1)
    d_inv_sqrt = np.power(d, -0.5)
    d_inv_sqrt[np.isinf(d_inv_sqrt)] = 0.
    d_mat_inv_sqrt = np.diag(d_inv_sqrt)

    normalized_adj = adj.dot(d_mat_inv_sqrt).transpose().dot(d_mat_inv_sqrt)
    return normalized_adj

def generate_sequences(data, seq_length, pred_length):
    """
    Generates input sequences and corresponding labels for time series forecasting.
    """
    x, y = [], []
    for i in range(len(data) - seq_length - pred_length + 1):
        x.append(data[i:i+seq_length])
        y.append(data[i+seq_length:i+seq_length+pred_length, :, 0])
    return np.array(x), np.array(y)

#Model Architecture (STGCN)

class GraphConv(Layer):
    """Custom Graph Convolutional Layer."""
    def __init__(self, filters, adj_matrix, **kwargs):
        super(GraphConv, self).__init__(**kwargs)
        self.filters = filters
        self.adj_matrix = tf.constant(adj_matrix, dtype=tf.float32)

    def build(self, input_shape):
        self.kernel = self.add_weight(name='kernel',
                                      shape=(input_shape[-1], self.filters),
                                      initializer='glorot_uniform',
                                      trainable=True)

    def call(self, inputs):
        support = tf.einsum('ij,btjf->btif', self.adj_matrix, inputs)
        output = tf.einsum('btif,fo->btio', support, self.kernel)
        return output # Activation will be applied outside

def stgcn_block(inputs, adj_matrix, filters, kernel_size):
    """A single Spatio-Temporal block."""
    t = Conv2D(filters, kernel_size=(1, kernel_size), padding='same', activation='relu')(inputs)
    s = GraphConv(filters, adj_matrix)(t)
    t2 = Conv2D(filters, kernel_size=(1, kernel_size), padding='same')(s)

    if inputs.shape[-1] != filters:
        residual = Conv2D(filters, kernel_size=(1, 1))(inputs)
    else:
        residual = inputs

    # Use Keras layers for addition and activation to avoid KerasTensor errors
    res_add = Add()([residual, t2])
    return ReLU()(res_add)

def build_stgcn_model(input_shape, adj_matrix, pred_length):
    """Builds the STGCN model with a corrected output structure."""
    inputs = Input(shape=input_shape)
    seq_length = input_shape[0] # Get sequence length from input shape

    x = stgcn_block(inputs, adj_matrix, filters=64, kernel_size=3)
    x = Dropout(0.3)(x)

    x = stgcn_block(x, adj_matrix, filters=64, kernel_size=3)
    x = Dropout(0.3)(x)

    # Final convolution to map features to a single value for each sensor/timestep
    x = Conv2D(1, kernel_size=(1, 1), activation='relu')(x)

    # This convolution processes the entire time sequence to produce an
    # output of the desired prediction length.
    # The kernel size (seq_length, 1) ensures it looks at all timesteps at once.
    x = Conv2D(pred_length, kernel_size=(seq_length, 1), activation='linear')(x)

    # Squeeze the time dimension, which is now of size 1
    x = Lambda(lambda z: tf.squeeze(z, axis=1))(x)

    # Permute the dimensions to match the label shape: (batch, pred_length, sensors)
    outputs = Permute((2, 1))(x)

    model = Model(inputs, outputs)
    return model

#Visualization Functions

def plot_training_history(history):
    """Plots the training and validation loss."""
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss (MAE)')
    plt.plot(history.history['val_loss'], label='Validation Loss (MAE)')
    plt.title('Model Training History')
    plt.xlabel('Epoch')
    plt.ylabel('Mean Absolute Error (Loss)')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_forecasts(model, X_val, y_val, scaler, pred_length, num_plots=5):
    """Visualizes model predictions against actuals."""
    predictions_normalized = model.predict(X_val)

    num_sensors = y_val.shape[2]
    num_features = scaler.scale_.shape[0]

    # Inverse transform predictions
    pred_dummy = np.zeros((predictions_normalized.shape[0], pred_length, num_sensors, num_features))
    pred_dummy[:, :, :, 0] = predictions_normalized
    pred_dummy = pred_dummy.reshape(-1, num_features)
    predictions = scaler.inverse_transform(pred_dummy)[:, 0].reshape(predictions_normalized.shape[0], pred_length, num_sensors)

    # Inverse transform actuals
    y_val_dummy = np.zeros((y_val.shape[0], pred_length, num_sensors, num_features))
    y_val_dummy[:, :, :, 0] = y_val
    y_val_dummy = y_val_dummy.reshape(-1, num_features)
    y_val_unnormalized = scaler.inverse_transform(y_val_dummy)[:, 0].reshape(y_val.shape[0], pred_length, num_sensors)

    for i in range(num_plots):
        random_sensor = np.random.randint(0, num_sensors)
        random_sample_idx = np.random.randint(0, len(X_val))

        plt.figure(figsize=(15, 6))
        plt.plot(predictions[random_sample_idx, :, random_sensor], label='Predicted Flow', marker='o')
        plt.plot(y_val_unnormalized[random_sample_idx, :, random_sensor], label='Actual Flow', marker='x')
        plt.title(f'Traffic Flow Forecast vs. Actual for Sensor #{random_sensor}')
        plt.xlabel('Time Step (5-minute intervals)')
        plt.ylabel('Traffic Flow')
        plt.legend()
        plt.grid(True)
        plt.show()

#Main Execution

if __name__ == '__main__':
    print("Loading data...")
    traffic_data, dist_matrix = load_data()
    adj_matrix = get_normalized_adj(dist_matrix)
    print("Data loaded and adjacency matrix computed.")

    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    traffic_data_reshaped = traffic_data.reshape(-1, traffic_data.shape[-1])
    traffic_data_normalized = scaler.fit_transform(traffic_data_reshaped).reshape(traffic_data.shape)
    print("Data normalized using StandardScaler.")

    seq_length = 12
    pred_length = 12
    print("Generating sequences...")
    X, y = generate_sequences(traffic_data_normalized, seq_length, pred_length)

    print(f"Sequence generation complete. X shape: {X.shape}, y shape: {y.shape}")

    train_split = int(0.7 * len(X))
    val_split = int(0.9 * len(X))
    X_train, y_train = X[:train_split], y[:train_split]
    X_val, y_val = X[train_split:val_split], y[train_split:val_split]
    X_test, y_test = X[val_split:], y[val_split:]
    print(f"Data split. Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")

    print("Building STGCN model...")
    input_shape = X_train.shape[1:]
    model = build_stgcn_model(input_shape, adj_matrix, pred_length)
    model.compile(optimizer='adam', loss='mae')
    model.summary()

    print("\nStarting model training...")
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=30,
        batch_size=32,
        verbose=1
    )
    print("Training complete.")

    print("\nEvaluating model on test set...")
    test_loss = model.evaluate(X_test, y_test)
    print(f"Test Loss (MAE): {test_loss}")

    print("\n--- Generating Visualization Results ---")
    plot_training_history(history)
    plot_forecasts(model, X_test, y_test, scaler, pred_length)
# Out:
# Loading data...
# Data loaded and adjacency matrix computed.
# Data normalized using StandardScaler.
# Generating sequences...
# Sequence generation complete. X shape: (17833, 12, 170, 3), y shape: (17833, 12, 170)
# Data split. Train: 12483, Val: 3566, Test: 1784
# Building STGCN model...
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 12, 170,   │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 12, 170,   │        640 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ graph_conv          │ (None, 12, 170,   │      4,096 │ conv2d[0][0]      │
# │ (GraphConv)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 12, 170,   │        256 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 12, 170,   │     12,352 │ graph_conv[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 12, 170,   │          0 │ conv2d_2[0][0],   │
# │                     │ 64)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 12, 170,   │          0 │ add[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 12, 170,   │          0 │ re_lu[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 12, 170,   │     12,352 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ graph_conv_1        │ (None, 12, 170,   │      4,096 │ conv2d_3[0][0]    │
# │ (GraphConv)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 12, 170,   │     12,352 │ graph_conv_1[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 12, 170,   │          0 │ dropout[0][0],    │
# │                     │ 64)               │            │ conv2d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 12, 170,   │          0 │ add_1[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 12, 170,   │          0 │ re_lu_1[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 12, 170,   │         65 │ dropout_1[0][0]   │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 1, 170,    │        156 │ conv2d_5[0][0]    │
# │                     │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 170, 12)   │          0 │ conv2d_6[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute (Permute)   │ (None, 12, 170)   │          0 │ lambda[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 46,365 (181.11 KB)
#  Trainable params: 46,365 (181.11 KB)
#  Non-trainable params: 0 (0.00 B)
# Starting model training...
# Epoch 1/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 359s 910ms/step - loss: 0.5707 - val_loss: 0.3885
# Epoch 2/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 368s 876ms/step - loss: 0.3451 - val_loss: 0.3149
# Epoch 3/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 393s 905ms/step - loss: 0.2505 - val_loss: 0.2391
# Epoch 4/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 379s 897ms/step - loss: 0.2045 - val_loss: 0.2317
# Epoch 5/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 384s 902ms/step - loss: 0.1803 - val_loss: 0.2446
# Epoch 6/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 380s 898ms/step - loss: 0.1684 - val_loss: 0.2468
# Epoch 7/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 351s 897ms/step - loss: 0.1625 - val_loss: 0.2199
# Epoch 8/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 339s 868ms/step - loss: 0.1558 - val_loss: 0.2337
# Epoch 9/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 392s 895ms/step - loss: 0.1533 - val_loss: 0.2183
# Epoch 10/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 383s 899ms/step - loss: 0.1517 - val_loss: 0.2109
# Epoch 11/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 335s 857ms/step - loss: 0.1489 - val_loss: 0.2009
# Epoch 12/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 345s 882ms/step - loss: 0.1483 - val_loss: 0.2059
# Epoch 13/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 389s 901ms/step - loss: 0.1471 - val_loss: 0.2150
# Epoch 14/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 382s 901ms/step - loss: 0.1456 - val_loss: 0.2039
# Epoch 15/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 381s 900ms/step - loss: 0.1447 - val_loss: 0.2099
# Epoch 16/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 370s 869ms/step - loss: 0.1451 - val_loss: 0.2229
# Epoch 17/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 351s 896ms/step - loss: 0.1440 - val_loss: 0.2244
# Epoch 18/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 351s 898ms/step - loss: 0.1423 - val_loss: 0.1994
# Epoch 19/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 338s 866ms/step - loss: 0.1429 - val_loss: 0.2089
# Epoch 20/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 390s 888ms/step - loss: 0.1422 - val_loss: 0.2086
# Epoch 21/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 349s 894ms/step - loss: 0.1423 - val_loss: 0.2168
# Epoch 22/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 383s 896ms/step - loss: 0.1408 - val_loss: 0.2257
# Epoch 23/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 379s 888ms/step - loss: 0.1409 - val_loss: 0.2169
# Epoch 24/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 337s 862ms/step - loss: 0.1399 - val_loss: 0.1812
# Epoch 25/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 395s 898ms/step - loss: 0.1403 - val_loss: 0.1989
# Epoch 26/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 339s 866ms/step - loss: 0.1388 - val_loss: 0.2070
# Epoch 27/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 339s 867ms/step - loss: 0.1395 - val_loss: 0.2026
# Epoch 28/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 396s 902ms/step - loss: 0.1386 - val_loss: 0.2111
# Epoch 29/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 378s 891ms/step - loss: 0.1384 - val_loss: 0.1970
# Epoch 30/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 383s 895ms/step - loss: 0.1380 - val_loss: 0.1972
# Training complete.
#
# Evaluating model on test set...
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 263ms/step - loss: 0.1868
# Test Loss (MAE): 0.1931397169828415
#
# --- Generating Visualization Results ---
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 265ms/step
